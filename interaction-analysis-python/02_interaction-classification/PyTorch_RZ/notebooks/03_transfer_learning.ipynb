# %% [markdown]
# # Transfer learning with PyTorch
# We're going to train a neural network to classify dogs and cats.

# %% [markdown]
# ## Init, helpers, utils, ...

# %%
from pprint import pprint
import random
import datetime
import time

from IPython.core.debugger import set_trace

import matplotlib.pyplot as plt
import numpy as np

#from ppt import utils
#from ppt.utils import attr

# %matplotlib inline

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import torchvision
from torchvision.datasets.folder import ImageFolder, default_loader

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
# Training helpers
def get_trainable(model_params):
    return (p for p in model_params if p.requires_grad)


def get_frozen(model_params):
    return (p for p in model_params if not p.requires_grad)


def all_trainable(model_params):
    return all(p.requires_grad for p in model_params)


def all_frozen(model_params):
    return all(not p.requires_grad for p in model_params)


def freeze_all(model_params):
    for param in model_params:
        param.requires_grad = False


# list(get_trainable(model.parameters()))
# list(get_frozen(model.parameters()))
# all_trainable(model.parameters())
# all_frozen(model.parameters())

# %% [markdown]
# # The Data - DogsCatsDataset

# %% [markdown]
# ## Transforms

# %%
from torchvision import transforms

IMG_SIZE = 224  #224  #defined by NN model input
_mean = [0.485, 0.456, 0.406]
_std = [0.229, 0.224, 0.225]


train_trans = transforms.Compose([
    transforms.Resize((IMG_SIZE,IMG_SIZE)),  #256  #(IMG_SIZE, IMG_SIZE)  # some images are pretty small
    #transforms.RandomCrop(IMG_SIZE),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(.3, .3, .3),
    transforms.ToTensor(),
    transforms.Normalize(_mean, _std),
])
val_trans = transforms.Compose([
    transforms.Resize((IMG_SIZE,IMG_SIZE)),  #256  #(IMG_SIZE, IMG_SIZE)
    #transforms.CenterCrop(IMG_SIZE),
    transforms.ToTensor(),
    transforms.Normalize(_mean, _std),
])

# %% [markdown]
# ## Dataset

# %%
# not necessary
#from ppt.utils import DogsCatsDataset

# %%
# sample data set
#train_ds = DogsCatsDataset("../data/raw", "sample/train", transform=train_trans)
#val_ds = DogsCatsDataset("../data/raw", "sample/valid", transform=val_trans)
#BATCH_SIZE = 2

# full data set
# use ppt.utils
#train_ds = DogsCatsDataset("../data/raw", "train", transform=train_trans)
#val_ds = DogsCatsDataset("../data/raw", "valid", transform=val_trans)
# use pytorch_version default
train_ds = ImageFolder("../data/raw/DUI/train", transform=train_trans, loader=default_loader)
val_ds = ImageFolder("../data/raw/DUI/valid", transform=train_trans, loader=default_loader)

BATCH_SIZE = 128  #2  #256  #512  #32  #220 for resnet152 on Dell Presison 5520 laptop, 400 for resnet18

n_classes = 2

# %%
len(train_ds), len(val_ds)
# Out:
# (13787, 1421)

# %% [raw]
# to_pil = torchvision.transforms.ToPILImage()
# img = to_pil(val_ds[4][0])
#
# imgplot = plt.imshow(img)

# %% [markdown]
# ## DataLoader
# Batch loading for datasets with multi-processing and different sample strategies.

# %%
from torch.utils.data import DataLoader


train_dl = DataLoader(
    train_ds,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=4,
)
val_dl = DataLoader(
    val_ds,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=4,
)

# %% [markdown]
# # The Model
# PyTorch offers quite a few [pre-trained networks](https://pytorch.org/docs/stable/torchvision/models.html) for you to use:
# - AlexNet
# - VGG
# - ResNet
# - SqueezeNet
# - DenseNet
# - Inception v3
#
# And there are more available via [pretrained-models.pytorch](https://github.com/Cadene/pretrained-models.pytorch)
# - NASNet,
# - ResNeXt,
# - InceptionV4,
# - InceptionResnetV2,
# - Xception,
# - DPN,
# - ...

# %%
from torchvision import models

model = models.resnet18(pretrained=True)
#model = models.resnet50(pretrained=True)
#model = models.resnet101(pretrained=True)
#model = models.resnet152(pretrained=True)

# %%
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
for param in model.parameters():
    param.requires_grad = True

#for param in model.parameters():
    #pprint(param)

# %%
'''# Freeze all parameters
for param in model.parameters():
    param.requires_grad = False'''
# Out:
# '# Freeze all parameters\nfor param in model.parameters():\n    param.requires_grad = False'

# %%
'''freeze_all(model.parameters())
assert all_frozen(model.parameters())'''
# Out:
# 'freeze_all(model.parameters())\nassert all_frozen(model.parameters())'

# %% [markdown]
# Replace the last layer with a linear layer. New layers have `requires_grad = True`.

# %%
'''model.fc = nn.Linear(512, n_classes)  # according to the model, 512 for resnet18, 2048 for resnet50 & resnet101 & resnet152'''
# Out:
# 'model.fc = nn.Linear(512, n_classes)  # according to the model, 512 for resnet18, 2048 for resnet50 & resnet101 & resnet152'

# %%
'''all_frozen(model.parameters())'''
# Out:
# 'all_frozen(model.parameters())'

# %%
'''# repetitive
def get_model(n_classes=2):
    model = models.resnet18(pretrained=True)
    freeze_all(model.parameters())
    model.fc = nn.Linear(512, n_classes)
    return model'''

#model = get_model().to(device)

model = model.to(device)

# %% [markdown]
# # The Loss

# %%
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# # The Optimizer

# %%
optimizer = torch.optim.Adam(
    get_trainable(model.parameters()),
    # model.fc.parameters(),
    lr=0.001,
    # momentum=0.9,
)

# %% [markdown]
# # The Train Loop

# %%
N_EPOCHS = 10  #1  #2  #10

# %%
for epoch in range(N_EPOCHS):
    
    # start epoch
    start_time = time.time()
    start_datetime = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"Epoch {epoch+1}/{N_EPOCHS}")
    print(f'  Start Time: {start_datetime}')
    
    # Train
    model.train()  # IMPORTANT
    
    running_loss, correct = 0.0, 0
    for X, y in train_dl:
        X, y = X.to(device), y.to(device)
        
        optimizer.zero_grad()
        # with torch.set_grad_enabled(True):
        y_ = model(X)
        loss = criterion(y_, y)

        loss.backward()
        optimizer.step()
        
        # Statistics
        print(f"    batch loss: {loss.item():0.3f}")
        _, y_label_ = torch.max(y_, 1)
        correct += (y_label_ == y).sum().item()
        running_loss += loss.item() * X.shape[0]
    
    print(f"  Train Loss: {running_loss / len(train_dl.dataset)}")
    print(f"  Train Acc:  {correct / len(train_dl.dataset)}")
    
    
    # Eval
    model.eval()  # IMPORTANT
    
    running_loss, correct = 0.0, 0
    with torch.no_grad():  # IMPORTANT
        for X, y in val_dl:
            X, y = X.to(device), y.to(device)
                    
            y_ = model(X)
        
            _, y_label_ = torch.max(y_, 1)
            correct += (y_label_ == y).sum().item()
            
            loss = criterion(y_, y)
            running_loss += loss.item() * X.shape[0]
    
    print(f"  Valid Loss: {running_loss / len(val_dl.dataset)}")
    print(f"  Valid Acc:  {correct / len(val_dl.dataset)}")
    
    # end epoch
    end_time = time.time()
    end_datetime = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    time_elapsed = end_time - start_time
    datetime_elapsed = str(datetime.timedelta(seconds = time_elapsed))
    print(f'  End Time: {end_datetime}')
    print(f'  Time Elapsed: {datetime_elapsed}')
    print()
# Out:
# Epoch 1/10
#   Start Time: 2019-01-23 22:18:59
#     batch loss: 9.633
#     batch loss: 5.655
#     batch loss: 3.728
#     batch loss: 3.668
#     batch loss: 2.196
#     batch loss: 1.859
#     batch loss: 2.134
#     batch loss: 1.077
#     batch loss: 1.090
#     batch loss: 0.463
#     batch loss: 0.796
#     batch loss: 0.638
#     batch loss: 0.530
#     batch loss: 0.458
#     batch loss: 0.399
#     batch loss: 0.360
#     batch loss: 0.410
#     batch loss: 0.503
#     batch loss: 0.376
#     batch loss: 0.380
#     batch loss: 0.240
#     batch loss: 0.285
#     batch loss: 0.141
#     batch loss: 0.233
#     batch loss: 0.357
#     batch loss: 0.445
#     batch loss: 0.244
#     batch loss: 0.269
#     batch loss: 0.341
#     batch loss: 0.214
#     batch loss: 0.251
#     batch loss: 0.296
#     batch loss: 0.216
#     batch loss: 0.212
#     batch loss: 0.261
#     batch loss: 0.268
#     batch loss: 0.273
#     batch loss: 0.245
#     batch loss: 0.249
#     batch loss: 0.214
#     batch loss: 0.352
#     batch loss: 0.275
#     batch loss: 0.247
#     batch loss: 0.272
#     batch loss: 0.212
#     batch loss: 0.218
#     batch loss: 0.215
#     batch loss: 0.182
#     batch loss: 0.257
#     batch loss: 0.222
#     batch loss: 0.247
#     batch loss: 0.282
#     batch loss: 0.205
#     batch loss: 0.151
#     batch loss: 0.254
#     batch loss: 0.210
#     batch loss: 0.176
#     batch loss: 0.201
#     batch loss: 0.127
#     batch loss: 0.243
#     batch loss: 0.150
#     batch loss: 0.209
#     batch loss: 0.269
#     batch loss: 0.414
#     batch loss: 0.241
#     batch loss: 0.198
#     batch loss: 0.166
#     batch loss: 0.149
#     batch loss: 0.321
#     batch loss: 0.172
#     batch loss: 0.261
#     batch loss: 0.141
#     batch loss: 0.212
#     batch loss: 0.149
#     batch loss: 0.215
#     batch loss: 0.203
#     batch loss: 0.227
#     batch loss: 0.179
#     batch loss: 0.183
#     batch loss: 0.256
#     batch loss: 0.250
#     batch loss: 0.193
#     batch loss: 0.186
#     batch loss: 0.178
#     batch loss: 0.170
#     batch loss: 0.215
#     batch loss: 0.210
#     batch loss: 0.204
#     batch loss: 0.147
#     batch loss: 0.196
#     batch loss: 0.283
#     batch loss: 0.236
#     batch loss: 0.183
#     batch loss: 0.212
#     batch loss: 0.208
#     batch loss: 0.241
#     batch loss: 0.275
#     batch loss: 0.190
#     batch loss: 0.186
#     batch loss: 0.180
#     batch loss: 0.255
#     batch loss: 0.090
#     batch loss: 0.239
#     batch loss: 0.235
#     batch loss: 0.204
#     batch loss: 0.238
#     batch loss: 0.176
#     batch loss: 0.139
#   Train Loss: 0.5213629099640861
#   Train Acc:  0.8869949952854138
#   Valid Loss: 0.21917852805501387
#   Valid Acc:  0.9225897255453905
#   End Time: 2019-01-23 22:22:46
#   Time Elapsed: 0:03:46.402720
#
# Epoch 2/10
#   Start Time: 2019-01-23 22:22:46
#     batch loss: 0.190
#     batch loss: 0.172
#     batch loss: 0.193
#     batch loss: 0.124
#     batch loss: 0.187
#     batch loss: 0.133
#     batch loss: 0.081
#     batch loss: 0.207
#     batch loss: 0.169
#     batch loss: 0.123
#     batch loss: 0.148
#     batch loss: 0.132
#     batch loss: 0.194
#     batch loss: 0.166
#     batch loss: 0.198
#     batch loss: 0.129
#     batch loss: 0.205
#     batch loss: 0.198
#     batch loss: 0.132
#     batch loss: 0.189
#     batch loss: 0.127
#     batch loss: 0.204
#     batch loss: 0.158
#     batch loss: 0.109
#     batch loss: 0.227
#     batch loss: 0.250
#     batch loss: 0.164
#     batch loss: 0.235
#     batch loss: 0.182
#     batch loss: 0.197
#     batch loss: 0.176
#     batch loss: 0.139
#     batch loss: 0.128
#     batch loss: 0.228
#     batch loss: 0.207
#     batch loss: 0.140
#     batch loss: 0.090
#     batch loss: 0.163
#     batch loss: 0.242
#     batch loss: 0.183
#     batch loss: 0.220
#     batch loss: 0.156
#     batch loss: 0.204
#     batch loss: 0.180
#     batch loss: 0.101
#     batch loss: 0.196
#     batch loss: 0.116
#     batch loss: 0.148
#     batch loss: 0.148
#     batch loss: 0.248
#     batch loss: 0.264
#     batch loss: 0.092
#     batch loss: 0.250
#     batch loss: 0.182
#     batch loss: 0.112
#     batch loss: 0.107
#     batch loss: 0.167
#     batch loss: 0.157
#     batch loss: 0.139
#     batch loss: 0.165
#     batch loss: 0.155
#     batch loss: 0.177
#     batch loss: 0.203
#     batch loss: 0.157
#     batch loss: 0.138
#     batch loss: 0.136
#     batch loss: 0.087
#     batch loss: 0.174
#     batch loss: 0.146
#     batch loss: 0.150
#     batch loss: 0.200
#     batch loss: 0.165
#     batch loss: 0.188
#     batch loss: 0.217
#     batch loss: 0.159
#     batch loss: 0.160
#     batch loss: 0.158
#     batch loss: 0.179
#     batch loss: 0.166
#     batch loss: 0.274
#     batch loss: 0.153
#     batch loss: 0.104
#     batch loss: 0.234
#     batch loss: 0.157
#     batch loss: 0.184
#     batch loss: 0.197
#     batch loss: 0.152
#     batch loss: 0.188
#     batch loss: 0.112
#     batch loss: 0.166
#     batch loss: 0.166
#     batch loss: 0.141
#     batch loss: 0.214
#     batch loss: 0.287
#     batch loss: 0.248
#     batch loss: 0.172
#     batch loss: 0.209
#     batch loss: 0.180
#     batch loss: 0.154
#     batch loss: 0.148
#     batch loss: 0.153
#     batch loss: 0.179
#     batch loss: 0.200
#     batch loss: 0.099
#     batch loss: 0.217
#     batch loss: 0.202
#     batch loss: 0.128
#     batch loss: 0.307
#   Train Loss: 0.17195537696723762
#   Train Acc:  0.935301370856604
#   Valid Loss: 0.1862243911189818
#   Valid Acc:  0.9303307529908516
#   End Time: 2019-01-23 22:26:40
#   Time Elapsed: 0:03:54.460545
#
# Epoch 3/10
#   Start Time: 2019-01-23 22:26:40
#     batch loss: 0.129
#     batch loss: 0.167
#     batch loss: 0.126
#     batch loss: 0.181
#     batch loss: 0.099
#     batch loss: 0.158
#     batch loss: 0.124
#     batch loss: 0.158
#     batch loss: 0.208
#     batch loss: 0.108
#     batch loss: 0.121
#     batch loss: 0.141
#     batch loss: 0.162
#     batch loss: 0.153
#     batch loss: 0.104
#     batch loss: 0.189
#     batch loss: 0.164
#     batch loss: 0.136
#     batch loss: 0.138
#     batch loss: 0.112
#     batch loss: 0.263
#     batch loss: 0.109
#     batch loss: 0.152
#     batch loss: 0.142
#     batch loss: 0.125
#     batch loss: 0.093
#     batch loss: 0.107
#     batch loss: 0.219
#     batch loss: 0.130
#     batch loss: 0.160
#     batch loss: 0.077
#     batch loss: 0.082
#     batch loss: 0.157
#     batch loss: 0.102
#     batch loss: 0.113
#     batch loss: 0.162
#     batch loss: 0.109
#     batch loss: 0.110
#     batch loss: 0.293
#     batch loss: 0.141
#     batch loss: 0.161
#     batch loss: 0.104
#     batch loss: 0.228
#     batch loss: 0.217
#     batch loss: 0.173
#     batch loss: 0.079
#     batch loss: 0.097
#     batch loss: 0.146
#     batch loss: 0.149
#     batch loss: 0.107
#     batch loss: 0.180
#     batch loss: 0.147
#     batch loss: 0.141
#     batch loss: 0.104
#     batch loss: 0.162
#     batch loss: 0.151
#     batch loss: 0.107
#     batch loss: 0.129
#     batch loss: 0.243
#     batch loss: 0.136
#     batch loss: 0.111
#     batch loss: 0.132
#     batch loss: 0.097
#     batch loss: 0.231
#     batch loss: 0.154
#     batch loss: 0.134
#     batch loss: 0.110
#     batch loss: 0.054
#     batch loss: 0.136
#     batch loss: 0.136
#     batch loss: 0.219
#     batch loss: 0.192
#     batch loss: 0.161
#     batch loss: 0.129
#     batch loss: 0.101
#     batch loss: 0.108
#     batch loss: 0.177
#     batch loss: 0.188
#     batch loss: 0.227
#     batch loss: 0.170
#     batch loss: 0.153
#     batch loss: 0.134
#     batch loss: 0.093
#     batch loss: 0.189
#     batch loss: 0.199
#     batch loss: 0.162
#     batch loss: 0.146
#     batch loss: 0.153
#     batch loss: 0.144
#     batch loss: 0.118
#     batch loss: 0.151
#     batch loss: 0.184
#     batch loss: 0.102
#     batch loss: 0.225
#     batch loss: 0.120
#     batch loss: 0.106
#     batch loss: 0.144
#     batch loss: 0.096
#     batch loss: 0.109
#     batch loss: 0.132
#     batch loss: 0.274
#     batch loss: 0.132
#     batch loss: 0.179
#     batch loss: 0.150
#     batch loss: 0.060
#     batch loss: 0.062
#     batch loss: 0.200
#     batch loss: 0.134
#   Train Loss: 0.14543377442210167
#   Train Acc:  0.9442228185972292
#   Valid Loss: 0.20701015859653546
#   Valid Acc:  0.9190710767065446
#   End Time: 2019-01-23 22:30:54
#   Time Elapsed: 0:04:13.815196
#
# Epoch 4/10
#   Start Time: 2019-01-23 22:30:54
#     batch loss: 0.131
#     batch loss: 0.118
#     batch loss: 0.152
#     batch loss: 0.145
#     batch loss: 0.132
#     batch loss: 0.113
#     batch loss: 0.117
#     batch loss: 0.057
#     batch loss: 0.078
#     batch loss: 0.094
#     batch loss: 0.056
#     batch loss: 0.081
#     batch loss: 0.067
#     batch loss: 0.175
#     batch loss: 0.119
#     batch loss: 0.131
#     batch loss: 0.119
#     batch loss: 0.063
#     batch loss: 0.331
#     batch loss: 0.118
#     batch loss: 0.118
#     batch loss: 0.200
#     batch loss: 0.107
#     batch loss: 0.174
#     batch loss: 0.148
#     batch loss: 0.166
#     batch loss: 0.076
#     batch loss: 0.153
#     batch loss: 0.084
#     batch loss: 0.143
#     batch loss: 0.115
#     batch loss: 0.096
#     batch loss: 0.135
#     batch loss: 0.128
#     batch loss: 0.090
#     batch loss: 0.141
#     batch loss: 0.190
#     batch loss: 0.082
#     batch loss: 0.171
#     batch loss: 0.238
#     batch loss: 0.096
#     batch loss: 0.170
#     batch loss: 0.095
#     batch loss: 0.126
#     batch loss: 0.193
#     batch loss: 0.079
#     batch loss: 0.091
#     batch loss: 0.094
#     batch loss: 0.119
#     batch loss: 0.130
#     batch loss: 0.141
#     batch loss: 0.129
#     batch loss: 0.090
#     batch loss: 0.123
#     batch loss: 0.170
#     batch loss: 0.110
#     batch loss: 0.077
#     batch loss: 0.103
#     batch loss: 0.097
#     batch loss: 0.169
#     batch loss: 0.110
#     batch loss: 0.219
#     batch loss: 0.260
#     batch loss: 0.148
#     batch loss: 0.093
#     batch loss: 0.103
#     batch loss: 0.112
#     batch loss: 0.127
#     batch loss: 0.085
#     batch loss: 0.156
#     batch loss: 0.179
#     batch loss: 0.056
#     batch loss: 0.140
#     batch loss: 0.057
#     batch loss: 0.179
#     batch loss: 0.206
#     batch loss: 0.100
#     batch loss: 0.146
#     batch loss: 0.067
#     batch loss: 0.152
#     batch loss: 0.164
#     batch loss: 0.164
#     batch loss: 0.157
#     batch loss: 0.116
#     batch loss: 0.154
#     batch loss: 0.191
#     batch loss: 0.123
#     batch loss: 0.103
#     batch loss: 0.165
#     batch loss: 0.116
#     batch loss: 0.132
#     batch loss: 0.127
#     batch loss: 0.108
#     batch loss: 0.153
#     batch loss: 0.073
#     batch loss: 0.093
#     batch loss: 0.116
#     batch loss: 0.068
#     batch loss: 0.229
#     batch loss: 0.124
#     batch loss: 0.163
#     batch loss: 0.091
#     batch loss: 0.244
#     batch loss: 0.118
#     batch loss: 0.131
#     batch loss: 0.143
#     batch loss: 0.067
#     batch loss: 0.157
#   Train Loss: 0.1299142667739587
#   Train Acc:  0.9516936244288098
#   Valid Loss: 0.1859829557311107
#   Valid Acc:  0.9268121041520057
#   End Time: 2019-01-23 22:34:47
#   Time Elapsed: 0:03:52.563913
#
# Epoch 5/10
#   Start Time: 2019-01-23 22:34:47
#     batch loss: 0.121
#     batch loss: 0.135
#     batch loss: 0.067
#     batch loss: 0.158
#     batch loss: 0.109
#     batch loss: 0.119
#     batch loss: 0.106
#     batch loss: 0.054
#     batch loss: 0.075
#     batch loss: 0.143
#     batch loss: 0.086
#     batch loss: 0.110
#     batch loss: 0.146
#     batch loss: 0.113
#     batch loss: 0.080
#     batch loss: 0.216
#     batch loss: 0.054
#     batch loss: 0.158
#     batch loss: 0.040
#     batch loss: 0.055
#     batch loss: 0.230
#     batch loss: 0.143
#     batch loss: 0.096
#     batch loss: 0.144
#     batch loss: 0.146
#     batch loss: 0.048
#     batch loss: 0.123
#     batch loss: 0.092
#     batch loss: 0.112
#     batch loss: 0.067
#     batch loss: 0.071
#     batch loss: 0.202
#     batch loss: 0.101
#     batch loss: 0.149
#     batch loss: 0.075
#     batch loss: 0.097
#     batch loss: 0.051
#     batch loss: 0.099
#     batch loss: 0.038
#     batch loss: 0.097
#     batch loss: 0.129
#     batch loss: 0.118
#     batch loss: 0.051
#     batch loss: 0.106
#     batch loss: 0.146
#     batch loss: 0.162
#     batch loss: 0.052
#     batch loss: 0.095
#     batch loss: 0.081
#     batch loss: 0.069
#     batch loss: 0.104
#     batch loss: 0.126
#     batch loss: 0.139
#     batch loss: 0.130
#     batch loss: 0.093
#     batch loss: 0.111
#     batch loss: 0.199
#     batch loss: 0.155
#     batch loss: 0.084
#     batch loss: 0.138
#     batch loss: 0.056
#     batch loss: 0.220
#     batch loss: 0.112
#     batch loss: 0.129
#     batch loss: 0.111
#     batch loss: 0.126
#     batch loss: 0.057
#     batch loss: 0.123
#     batch loss: 0.090
#     batch loss: 0.115
#     batch loss: 0.117
#     batch loss: 0.070
#     batch loss: 0.080
#     batch loss: 0.110
#     batch loss: 0.082
#     batch loss: 0.217
#     batch loss: 0.162
#     batch loss: 0.180
#     batch loss: 0.075
#     batch loss: 0.093
#     batch loss: 0.206
#     batch loss: 0.081
#     batch loss: 0.108
#     batch loss: 0.088
#     batch loss: 0.084
#     batch loss: 0.089
#     batch loss: 0.165
#     batch loss: 0.209
#     batch loss: 0.080
#     batch loss: 0.064
#     batch loss: 0.216
#     batch loss: 0.199
#     batch loss: 0.176
#     batch loss: 0.105
#     batch loss: 0.109
#     batch loss: 0.154
#     batch loss: 0.246
#     batch loss: 0.178
#     batch loss: 0.135
#     batch loss: 0.104
#     batch loss: 0.109
#     batch loss: 0.123
#     batch loss: 0.178
#     batch loss: 0.143
#     batch loss: 0.182
#     batch loss: 0.064
#     batch loss: 0.140
#     batch loss: 0.117
#   Train Loss: 0.11844933885426279
#   Train Acc:  0.9569159353013709
#   Valid Loss: 0.17426877888804335
#   Valid Acc:  0.9338494018296974
#   End Time: 2019-01-23 22:38:47
#   Time Elapsed: 0:03:59.886264
#
# Epoch 6/10
#   Start Time: 2019-01-23 22:38:47
#     batch loss: 0.137
#     batch loss: 0.048
#     batch loss: 0.105
#     batch loss: 0.075
#     batch loss: 0.099
#     batch loss: 0.064
#     batch loss: 0.096
#     batch loss: 0.091
#     batch loss: 0.067
#     batch loss: 0.043
#     batch loss: 0.066
#     batch loss: 0.101
#     batch loss: 0.050
#     batch loss: 0.076
#     batch loss: 0.202
#     batch loss: 0.042
#     batch loss: 0.087
#     batch loss: 0.106
#     batch loss: 0.116
#     batch loss: 0.101
#     batch loss: 0.060
#     batch loss: 0.131
#     batch loss: 0.087
#     batch loss: 0.042
#     batch loss: 0.078
#     batch loss: 0.140
#     batch loss: 0.092
#     batch loss: 0.073
#     batch loss: 0.097
#     batch loss: 0.082
#     batch loss: 0.129
#     batch loss: 0.208
#     batch loss: 0.158
#     batch loss: 0.097
#     batch loss: 0.062
#     batch loss: 0.140
#     batch loss: 0.074
#     batch loss: 0.178
#     batch loss: 0.107
#     batch loss: 0.139
#     batch loss: 0.107
#     batch loss: 0.112
#     batch loss: 0.150
#     batch loss: 0.148
#     batch loss: 0.094
#     batch loss: 0.130
#     batch loss: 0.137
#     batch loss: 0.090
#     batch loss: 0.080
#     batch loss: 0.104
#     batch loss: 0.099
#     batch loss: 0.161
#     batch loss: 0.180
#     batch loss: 0.164
#     batch loss: 0.109
#     batch loss: 0.099
#     batch loss: 0.065
#     batch loss: 0.110
#     batch loss: 0.148
#     batch loss: 0.141
#     batch loss: 0.077
#     batch loss: 0.138
#     batch loss: 0.055
#     batch loss: 0.105
#     batch loss: 0.069
#     batch loss: 0.069
#     batch loss: 0.118
#     batch loss: 0.139
#     batch loss: 0.162
#     batch loss: 0.056
#     batch loss: 0.145
#     batch loss: 0.135
#     batch loss: 0.141
#     batch loss: 0.166
#     batch loss: 0.150
#     batch loss: 0.118
#     batch loss: 0.114
#     batch loss: 0.059
#     batch loss: 0.085
#     batch loss: 0.042
#     batch loss: 0.220
#     batch loss: 0.109
#     batch loss: 0.112
#     batch loss: 0.139
#     batch loss: 0.078
#     batch loss: 0.092
#     batch loss: 0.129
#     batch loss: 0.112
#     batch loss: 0.077
#     batch loss: 0.077
#     batch loss: 0.140
#     batch loss: 0.097
#     batch loss: 0.089
#     batch loss: 0.135
#     batch loss: 0.118
#     batch loss: 0.107
#     batch loss: 0.072
#     batch loss: 0.101
#     batch loss: 0.100
#     batch loss: 0.085
#     batch loss: 0.101
#     batch loss: 0.054
#     batch loss: 0.062
#     batch loss: 0.033
#     batch loss: 0.129
#     batch loss: 0.099
#     batch loss: 0.041
#     batch loss: 0.048
#   Train Loss: 0.10450898917476875
#   Train Acc:  0.9620657140784797
#   Valid Loss: 0.18872650907251048
#   Valid Acc:  0.9359605911330049
#   End Time: 2019-01-23 22:42:47
#   Time Elapsed: 0:04:00.664359
#
# Epoch 7/10
#   Start Time: 2019-01-23 22:42:47
#     batch loss: 0.055
#     batch loss: 0.049
#     batch loss: 0.104
#     batch loss: 0.062
#     batch loss: 0.090
#     batch loss: 0.036
#     batch loss: 0.045
#     batch loss: 0.059
#     batch loss: 0.131
#     batch loss: 0.179
#     batch loss: 0.090
#     batch loss: 0.107
#     batch loss: 0.057
#     batch loss: 0.115
#     batch loss: 0.071
#     batch loss: 0.062
#     batch loss: 0.025
#     batch loss: 0.144
#     batch loss: 0.106
#     batch loss: 0.121
#     batch loss: 0.116
#     batch loss: 0.118
#     batch loss: 0.085
#     batch loss: 0.067
#     batch loss: 0.070
#     batch loss: 0.108
#     batch loss: 0.133
#     batch loss: 0.096
#     batch loss: 0.057
#     batch loss: 0.086
#     batch loss: 0.065
#     batch loss: 0.046
#     batch loss: 0.092
#     batch loss: 0.158
#     batch loss: 0.066
#     batch loss: 0.086
#     batch loss: 0.156
#     batch loss: 0.060
#     batch loss: 0.047
#     batch loss: 0.042
#     batch loss: 0.061
#     batch loss: 0.085
#     batch loss: 0.119
#     batch loss: 0.169
#     batch loss: 0.085
#     batch loss: 0.123
#     batch loss: 0.119
#     batch loss: 0.063
#     batch loss: 0.081
#     batch loss: 0.050
#     batch loss: 0.160
#     batch loss: 0.073
#     batch loss: 0.099
#     batch loss: 0.095
#     batch loss: 0.134
#     batch loss: 0.121
#     batch loss: 0.124
#     batch loss: 0.149
#     batch loss: 0.110
#     batch loss: 0.081
#     batch loss: 0.070
#     batch loss: 0.062
#     batch loss: 0.122
#     batch loss: 0.035
#     batch loss: 0.068
#     batch loss: 0.199
#     batch loss: 0.136
#     batch loss: 0.097
#     batch loss: 0.112
#     batch loss: 0.167
#     batch loss: 0.116
#     batch loss: 0.061
#     batch loss: 0.083
#     batch loss: 0.142
#     batch loss: 0.085
#     batch loss: 0.082
#     batch loss: 0.149
#     batch loss: 0.062
#     batch loss: 0.081
#     batch loss: 0.196
#     batch loss: 0.085
#     batch loss: 0.057
#     batch loss: 0.136
#     batch loss: 0.084
#     batch loss: 0.110
#     batch loss: 0.049
#     batch loss: 0.089
#     batch loss: 0.117
#     batch loss: 0.074
#     batch loss: 0.096
#     batch loss: 0.064
#     batch loss: 0.085
#     batch loss: 0.048
#     batch loss: 0.133
#     batch loss: 0.053
#     batch loss: 0.044
#     batch loss: 0.101
#     batch loss: 0.146
#     batch loss: 0.072
#     batch loss: 0.050
#     batch loss: 0.115
#     batch loss: 0.153
#     batch loss: 0.051
#     batch loss: 0.139
#     batch loss: 0.067
#     batch loss: 0.097
#     batch loss: 0.113
#     batch loss: 0.121
#   Train Loss: 0.09472710499705471
#   Train Acc:  0.9659099151374483
#   Valid Loss: 0.15768261418470106
#   Valid Acc:  0.9437016185784659
#   End Time: 2019-01-23 22:46:44
#   Time Elapsed: 0:03:56.486987
#
# Epoch 8/10
#   Start Time: 2019-01-23 22:46:44
#     batch loss: 0.106
#     batch loss: 0.099
#     batch loss: 0.052
#     batch loss: 0.058
#     batch loss: 0.124
#     batch loss: 0.091
#     batch loss: 0.037
#     batch loss: 0.081
#     batch loss: 0.088
#     batch loss: 0.086
#     batch loss: 0.040
#     batch loss: 0.047
#     batch loss: 0.021
#     batch loss: 0.056
#     batch loss: 0.090
#     batch loss: 0.103
#     batch loss: 0.063
#     batch loss: 0.165
#     batch loss: 0.031
#     batch loss: 0.026
#     batch loss: 0.034
#     batch loss: 0.079
#     batch loss: 0.097
#     batch loss: 0.096
#     batch loss: 0.065
#     batch loss: 0.035
#     batch loss: 0.047
#     batch loss: 0.048
#     batch loss: 0.017
#     batch loss: 0.090
#     batch loss: 0.031
#     batch loss: 0.067
#     batch loss: 0.083
#     batch loss: 0.052
#     batch loss: 0.078
#     batch loss: 0.116
#     batch loss: 0.041
#     batch loss: 0.083
#     batch loss: 0.029
#     batch loss: 0.075
#     batch loss: 0.032
#     batch loss: 0.023
#     batch loss: 0.138
#     batch loss: 0.045
#     batch loss: 0.035
#     batch loss: 0.040
#     batch loss: 0.069
#     batch loss: 0.022
#     batch loss: 0.113
#     batch loss: 0.127
#     batch loss: 0.107
#     batch loss: 0.168
#     batch loss: 0.077
#     batch loss: 0.145
#     batch loss: 0.045
#     batch loss: 0.081
#     batch loss: 0.141
#     batch loss: 0.080
#     batch loss: 0.056
#     batch loss: 0.084
#     batch loss: 0.118
#     batch loss: 0.064
#     batch loss: 0.092
#     batch loss: 0.098
#     batch loss: 0.096
#     batch loss: 0.099
#     batch loss: 0.085
#     batch loss: 0.103
#     batch loss: 0.110
#     batch loss: 0.159
#     batch loss: 0.036
#     batch loss: 0.063
#     batch loss: 0.028
#     batch loss: 0.062
#     batch loss: 0.105
#     batch loss: 0.073
#     batch loss: 0.057
#     batch loss: 0.100
#     batch loss: 0.116
#     batch loss: 0.092
#     batch loss: 0.128
#     batch loss: 0.071
#     batch loss: 0.083
#     batch loss: 0.116
#     batch loss: 0.086
#     batch loss: 0.055
#     batch loss: 0.033
#     batch loss: 0.065
#     batch loss: 0.084
#     batch loss: 0.057
#     batch loss: 0.047
#     batch loss: 0.095
#     batch loss: 0.109
#     batch loss: 0.095
#     batch loss: 0.028
#     batch loss: 0.160
#     batch loss: 0.161
#     batch loss: 0.126
#     batch loss: 0.122
#     batch loss: 0.101
#     batch loss: 0.068
#     batch loss: 0.050
#     batch loss: 0.107
#     batch loss: 0.077
#     batch loss: 0.132
#     batch loss: 0.112
#     batch loss: 0.076
#     batch loss: 0.093
#   Train Loss: 0.08002523455236253
#   Train Acc:  0.9700442445782259
#   Valid Loss: 0.21817338872467607
#   Valid Acc:  0.9148486980999296
#   End Time: 2019-01-23 22:50:35
#   Time Elapsed: 0:03:50.942137
#
# Epoch 9/10
#   Start Time: 2019-01-23 22:50:35
#     batch loss: 0.068
#     batch loss: 0.067
#     batch loss: 0.040
#     batch loss: 0.077
#     batch loss: 0.056
#     batch loss: 0.044
#     batch loss: 0.069
#     batch loss: 0.014
#     batch loss: 0.038
#     batch loss: 0.124
#     batch loss: 0.046
#     batch loss: 0.100
#     batch loss: 0.065
#     batch loss: 0.049
#     batch loss: 0.068
#     batch loss: 0.088
#     batch loss: 0.040
#     batch loss: 0.066
#     batch loss: 0.095
#     batch loss: 0.067
#     batch loss: 0.028
#     batch loss: 0.072
#     batch loss: 0.153
#     batch loss: 0.048
#     batch loss: 0.049
#     batch loss: 0.053
#     batch loss: 0.072
#     batch loss: 0.072
#     batch loss: 0.035
#     batch loss: 0.095
#     batch loss: 0.070
#     batch loss: 0.045
#     batch loss: 0.096
#     batch loss: 0.083
#     batch loss: 0.069
#     batch loss: 0.053
#     batch loss: 0.092
#     batch loss: 0.090
#     batch loss: 0.049
#     batch loss: 0.050
#     batch loss: 0.061
#     batch loss: 0.049
#     batch loss: 0.033
#     batch loss: 0.091
#     batch loss: 0.094
#     batch loss: 0.111
#     batch loss: 0.025
#     batch loss: 0.074
#     batch loss: 0.018
#     batch loss: 0.075
#     batch loss: 0.067
#     batch loss: 0.066
#     batch loss: 0.051
#     batch loss: 0.141
#     batch loss: 0.033
#     batch loss: 0.055
#     batch loss: 0.020
#     batch loss: 0.042
#     batch loss: 0.079
#     batch loss: 0.084
#     batch loss: 0.099
#     batch loss: 0.103
#     batch loss: 0.018
#     batch loss: 0.041
#     batch loss: 0.041
#     batch loss: 0.094
#     batch loss: 0.074
#     batch loss: 0.089
#     batch loss: 0.122
#     batch loss: 0.074
#     batch loss: 0.083
#     batch loss: 0.061
#     batch loss: 0.082
#     batch loss: 0.071
#     batch loss: 0.032
#     batch loss: 0.074
#     batch loss: 0.049
#     batch loss: 0.047
#     batch loss: 0.176
#     batch loss: 0.057
#     batch loss: 0.033
#     batch loss: 0.096
#     batch loss: 0.060
#     batch loss: 0.124
#     batch loss: 0.087
#     batch loss: 0.045
#     batch loss: 0.064
#     batch loss: 0.045
#     batch loss: 0.089
#     batch loss: 0.045
#     batch loss: 0.152
#     batch loss: 0.083
#     batch loss: 0.058
#     batch loss: 0.083
#     batch loss: 0.104
#     batch loss: 0.080
#     batch loss: 0.106
#     batch loss: 0.045
#     batch loss: 0.044
#     batch loss: 0.043
#     batch loss: 0.041
#     batch loss: 0.099
#     batch loss: 0.131
#     batch loss: 0.067
#     batch loss: 0.205
#     batch loss: 0.068
#     batch loss: 0.087
#     batch loss: 0.124
#   Train Loss: 0.07132927406274737
#   Train Acc:  0.9732356567781243
#   Valid Loss: 0.20435148520548524
#   Valid Acc:  0.9317382125263899
#   End Time: 2019-01-23 22:54:25
#   Time Elapsed: 0:03:49.915809
#
# Epoch 10/10
#   Start Time: 2019-01-23 22:54:25
#     batch loss: 0.070
#     batch loss: 0.043
#     batch loss: 0.069
#     batch loss: 0.079
#     batch loss: 0.027
#     batch loss: 0.036
#     batch loss: 0.052
#     batch loss: 0.074
#     batch loss: 0.072
#     batch loss: 0.026
#     batch loss: 0.023
#     batch loss: 0.024
#     batch loss: 0.010
#     batch loss: 0.044
#     batch loss: 0.008
#     batch loss: 0.043
#     batch loss: 0.032
#     batch loss: 0.040
#     batch loss: 0.044
#     batch loss: 0.067
#     batch loss: 0.044
#     batch loss: 0.055
#     batch loss: 0.030
#     batch loss: 0.032
#     batch loss: 0.016
#     batch loss: 0.041
#     batch loss: 0.083
#     batch loss: 0.138
#     batch loss: 0.110
#     batch loss: 0.031
#     batch loss: 0.026
#     batch loss: 0.058
#     batch loss: 0.025
#     batch loss: 0.025
#     batch loss: 0.043
#     batch loss: 0.093
#     batch loss: 0.055
#     batch loss: 0.064
#     batch loss: 0.065
#     batch loss: 0.035
#     batch loss: 0.116
#     batch loss: 0.070
#     batch loss: 0.070
#     batch loss: 0.041
#     batch loss: 0.060
#     batch loss: 0.045
#     batch loss: 0.011
#     batch loss: 0.119
#     batch loss: 0.096
#     batch loss: 0.033
#     batch loss: 0.054
#     batch loss: 0.039
#     batch loss: 0.071
#     batch loss: 0.073
#     batch loss: 0.079
#     batch loss: 0.086
#     batch loss: 0.042
#     batch loss: 0.053
#     batch loss: 0.099
#     batch loss: 0.053
#     batch loss: 0.075
#     batch loss: 0.023
#     batch loss: 0.048
#     batch loss: 0.061
#     batch loss: 0.052
#     batch loss: 0.070
#     batch loss: 0.016
#     batch loss: 0.051
#     batch loss: 0.067
#     batch loss: 0.062
#     batch loss: 0.024
#     batch loss: 0.019
#     batch loss: 0.077
#     batch loss: 0.123
#     batch loss: 0.046
#     batch loss: 0.015
#     batch loss: 0.115
#     batch loss: 0.020
#     batch loss: 0.147
#     batch loss: 0.072
#     batch loss: 0.028
#     batch loss: 0.059
#     batch loss: 0.036
#     batch loss: 0.071
#     batch loss: 0.090
#     batch loss: 0.075
#     batch loss: 0.171
#     batch loss: 0.073
#     batch loss: 0.031
#     batch loss: 0.080
#     batch loss: 0.051
#     batch loss: 0.150
#     batch loss: 0.075
#     batch loss: 0.085
#     batch loss: 0.132
#     batch loss: 0.073
#     batch loss: 0.082
#     batch loss: 0.061
#     batch loss: 0.058
#     batch loss: 0.046
#     batch loss: 0.130
#     batch loss: 0.053
#     batch loss: 0.124
#     batch loss: 0.084
#     batch loss: 0.153
#     batch loss: 0.067
#     batch loss: 0.091
#     batch loss: 0.114
#   Train Loss: 0.06268337020457175
#   Train Acc:  0.9768622615507362
#   Valid Loss: 0.1815347560877367
#   Valid Acc:  0.9373680506685432
#   End Time: 2019-01-23 22:58:12
#   Time Elapsed: 0:03:46.924908

# %% [markdown]
# ** -- above is the result of crop extent data set -- **

# %% [markdown]
# # Predict with Trained Model
#
# Pickle the trained model and predict image with it.

# %%
# save the trained model weights
model_weights_path = '../data/saved_model_weights/resnet18_whole'

# !!!only use it when you WANT to save a trained model weights!!!
#torch.save(model.state_dict(), model_weights_path)

# %%
# load the trained model
from torchvision import models

model = models.resnet18(pretrained=True)
#model = models.resnet50(pretrained=True)
#model = models.resnet101(pretrained=True)
#model = models.resnet152(pretrained=True)

model.load_state_dict(torch.load(model_weights_path))

model = model.to(device)

# %%
# use trained model to predict a pair of people in a new image

# test data set
test_ds = ImageFolder("../data/raw/DUI/test", transform=val_trans, loader=default_loader)
print(f'len(test_ds) = {len(test_ds)}. ')

test_dl = DataLoader(
    test_ds,
    batch_size=1,
    shuffle=False,
    num_workers=4,
)

print(f'test_ds[99]: \n{test_ds[99]}')
print(f'test_ds[99][1]: \n{test_ds[99][1]}')
# Out:
# len(test_ds) = 1421.
# test_ds[99]:
# (tensor([[[ 0.1083,  0.0912,  0.0056,  ..., -2.1179, -2.1179, -2.1179],
#          [ 0.1083,  0.0912,  0.0398,  ..., -2.1179, -2.1179, -2.1179],
#          [ 0.1083,  0.1083,  0.0741,  ..., -2.1179, -2.1179, -2.1179],
#          ...,
#          [-2.1179, -2.1179, -2.1179,  ..., -0.7822, -0.6452, -0.4739],
#          [-2.1179, -2.1179, -2.1179,  ..., -0.8507, -0.6794, -0.4911],
#          [-2.1179, -2.1179, -2.1179,  ..., -0.8335, -0.7650, -0.5767]],
#
#         [[ 0.2227,  0.2052,  0.1176,  ..., -2.0357, -2.0357, -2.0357],
#          [ 0.2227,  0.2052,  0.1527,  ..., -2.0357, -2.0357, -2.0357],
#          [ 0.2227,  0.2227,  0.1877,  ..., -2.0357, -2.0357, -2.0357],
#          ...,
#          [-2.0357, -2.0357, -2.0357,  ..., -0.6702, -0.5301, -0.3550],
#          [-2.0357, -2.0357, -2.0357,  ..., -0.7402, -0.5651, -0.3725],
#          [-2.0357, -2.0357, -2.0357,  ..., -0.7227, -0.6527, -0.4601]],
#
#         [[ 0.4962,  0.4788,  0.3916,  ..., -1.8044, -1.8044, -1.8044],
#          [ 0.4962,  0.4788,  0.4265,  ..., -1.8044, -1.8044, -1.8044],
#          [ 0.4962,  0.4962,  0.4614,  ..., -1.8044, -1.8044, -1.8044],
#          ...,
#          [-1.8044, -1.8044, -1.8044,  ..., -0.4450, -0.3055, -0.1835],
#          [-1.8044, -1.8044, -1.8044,  ..., -0.5147, -0.3578, -0.1835],
#          [-1.8044, -1.8044, -1.8044,  ..., -0.5147, -0.4450, -0.2881]]]), 0)
# test_ds[99][1]:
# 0

# %%
# predict

# Eval
model.eval()  # IMPORTANT

with torch.no_grad():  # IMPORTANT
    for X, y in test_dl:
        X, y = X.to(device), y.to(device)
        print(f'y: \t\t\t{y}')

        y_ = model(X)
        _, y_label_ = torch.max(y_, 1)
        print(f'y_label_: \t\t{y_label_}')
        
        is_correct = 'correct' if y_label_ == y else 'wrong'
        print(f'is_correct: \t{is_correct}\n')

#print(f"  Valid Loss: {running_loss / len(val_dl.dataset)}")
#print(f"  Valid Acc:  {correct / len(val_dl.dataset)}")
# Out:
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([0], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	correct
#
# ...
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([0], device='cuda:0')
# is_correct: 	wrong
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct
#
# y: 			tensor([1], device='cuda:0')
# y_label_: 		tensor([1], device='cuda:0')
# is_correct: 	correct

# %% [markdown]
# Recommended approach for saving a model
# There are two main approaches for serializing and restoring a model.
#
# ### The first (recommended) saves and loads only the model parameters:
#
# torch.save(the_model.state_dict(), PATH)
#
# Then later:
#
# the_model = TheModelClass(*args, **kwargs)
# the_model.load_state_dict(torch.load(PATH))
#
# ### The second saves and loads the entire model:
#
# torch.save(the_model, PATH)
# Then later:
#
# the_model = torch.load(PATH)
# However in this case, the serialized data is bound to the specific classes and the exact directory structure used, so it can break in various ways when used in other projects, or after some serious refactors.
